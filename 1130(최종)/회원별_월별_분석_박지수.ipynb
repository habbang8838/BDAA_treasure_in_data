# %% [markdown]
# <a href="https://colab.research.google.com/github/habbang8838/BDAA_treasure_in_data/blob/main/CJ%EC%A0%9C%EC%9D%BC%EC%A0%9C%EB%8B%B9_%EC%A3%BC%EB%AC%B8_%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# df_id.to_csv('CJ 아이디별 조회.csv', encoding='utf-8')

# %% [markdown]
# # CJ 아이디별 파일 다운받고, 여기서부터 코딩 실행해주세요!!

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import matplotlib
import platform
import matplotlib.pyplot as plt

# %matplotlib inline 

if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family = font_name)
else:
    rc('font',family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus']=False
# %matplotlib inline

# %%
df_id = pd.read_csv('CJ 아이디별 조회.csv')

# %%
df_id['주문접수일시'] = pd.to_datetime(df_id['주문접수일시'])

# %%
df_id['주문날짜'] = df_id['주문번호']//(10**8)
df_id['주문날짜'].astype(str)
df_id['주문날짜'] = pd.to_datetime(df_id['주문날짜'], format = "%Y%m%d")

# %%
df_id_test = df_id.groupby(['아이디']).count()

# %%
df_id_cond = df_id_test[df_id_test['주문접수일시'] >= 2]

# %%
df_id_cond.sort_values(by='주문접수일시', ascending=False)
# Out:
#           주문접수일시  주문번호  유입채널 대분류  시간대 대분류  주문월  판매자상품명  판매가  표준카테고리  주문날짜
# 아이디
# love****     220   220       220      220  220     220  220     220   220
# blue****     196   196       196      196  196     196  196     196   196
# csh3718      165   165       165      165  165     165  165     165   165
# jung****     135   135       135      135  135     135  135     135   135
# yoon****     130   130       130      130  130     130  130     130   130
# ...          ...   ...       ...      ...  ...     ...  ...     ...   ...
# km92****       3     3         3        3    3       3    3       3     3
# kma1****       3     3         3        3    3       3    3       3     3
# kma1119        3     3         3        3    3       3    3       3     3
# kmastin        3     3         3        3    3       3    3       3     3
# kmhjbr1        3     3         3        3    3       3    3       3     3
#
# [5774 rows x 9 columns]

# %%
df_id_cond[df_id_cond['주문접수일시'] == 220].index
# Out:
# Index(['love****'], dtype='object', name='아이디')

# %%
df_mem1 = df_id[df_id['아이디'] == 'love****']

# %%
df_mem1
# Out:
#                  주문접수일시              주문번호     유입채널 대분류  시간대 대분류  주문월  \
# 0   2022-01-07 06:55:35  2022010712865550         가격비교  06 ~ 09    1
# 1   2022-01-07 06:57:53  2022010712865630         가격비교  06 ~ 09    1
# 2   2022-01-10 09:36:32  2022011013280040           검색  09 ~ 12    1
# 3   2022-01-10 11:56:34  2022011013300450     CJ 앱/사이트  09 ~ 12    1
# 4   2022-01-10 16:28:22  2022011013337260         가격비교  15 ~ 18    1
# ..                  ...               ...          ...      ...  ...
# 215 2022-07-06 03:12:42  2022070618027370     CJ 앱/사이트  03 ~ 06    7
# 216 2022-07-06 03:12:42  2022070618027370     CJ 앱/사이트  03 ~ 06    7
# 217 2022-07-06 15:59:10  2022070618106970  기타 및 이벤트 광고  15 ~ 18    7
# 218 2022-07-06 15:59:10  2022070618106970  기타 및 이벤트 광고  15 ~ 18    7
# 219 2022-07-11 16:14:08  2022071118754740     CJ 앱/사이트  15 ~ 18    7
#
#           아이디                                             판매자상품명    판매가  \
# ...

# %%
df_mem1['시간대 대분류'].value_counts()
# Out:
# 21 ~ 00    50
# 15 ~ 18    37
# 00 ~ 03    33
# 12 ~ 15    26
# 18 ~ 21    26
# 09 ~ 12    23
# 06 ~ 09    16
# 03 ~ 06     9
# Name: 시간대 대분류, dtype: int64

# %%
df_mem1['유입채널 대분류'].value_counts()
# Out:
# CJ 앱/사이트       163
# 가격비교            32
# 기타 및 이벤트 광고     12
# 모바일 공유           8
# 검색               5
# Name: 유입채널 대분류, dtype: int64

# %%
# 위 사용자는 주로 언제 주문을 할까?
sns.countplot(x='시간대 대분류', data=df_mem1, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_mem1_1 = df_mem1[df_mem1['유입채널 대분류'] == 'CJ 앱/사이트']
# CJ 앱/사이트에서는 언제 홍보하는게 좋을까?

# %%
sns.countplot(x='시간대 대분류', data=df_mem1_1, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_mem1_2 = df_mem1[df_mem1['유입채널 대분류'] == '가격비교']

# %%
sns.countplot(x='시간대 대분류', data=df_mem1_2, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# 가격비교는 언제 활성화시키는게 좋을까?
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %% [markdown]
# ### -> 이 회원은 주로 21 ~ 00시, 00 ~ 03시 야간 시간대에 대체로 많이 주문하며,
# ### CJ 채널에서 직접 주문은 21 ~ 03시, 가격 비교로서의 주문은 12 ~ 00시에 많음을 알 수 있습니다.

# %%
df_mem1_1
# Out:
#                  주문접수일시              주문번호  유입채널 대분류  시간대 대분류  주문월       아이디  \
# 3   2022-01-10 11:56:34  2022011013300450  CJ 앱/사이트  09 ~ 12    1  love****
# 6   2022-01-21 10:27:34  2022012114917170  CJ 앱/사이트  09 ~ 12    1  love****
# 7   2022-01-26 16:48:00  2022012615681210  CJ 앱/사이트  15 ~ 18    1  love****
# 9   2022-02-05 18:05:15  2022020516790290  CJ 앱/사이트  18 ~ 21    2  love****
# 11  2022-02-08 22:40:48  2022020817414840  CJ 앱/사이트  21 ~ 00    2  love****
# ..                  ...               ...       ...      ...  ...       ...
# 213 2022-07-05 13:38:10  2022070517934160  CJ 앱/사이트  12 ~ 15    7  love****
# 214 2022-07-06 03:12:42  2022070618027370  CJ 앱/사이트  03 ~ 06    7  love****
# 215 2022-07-06 03:12:42  2022070618027370  CJ 앱/사이트  03 ~ 06    7  love****
# 216 2022-07-06 03:12:42  2022070618027370  CJ 앱/사이트  03 ~ 06    7  love****
# 219 2022-07-11 16:14:08  2022071118754740  CJ 앱/사이트  15 ~ 18    7  love****
#
# ...

# %%
df_mem1_1['판매자상품명'].value_counts()
# Out:
# 비비고 사골곰탕 500g x18봉                                                  22
# [Lpoint 1,000P 지급]햇반 작은공기, 100% 현미밥 x 36개 특가 (1,000set 한정)          14
# [CJ직배송]포도씨유 900ML X 2개                                              11
# 비비고 BEST 볶음밥 3종 특가[불고기 비빔밥 + 매콤부추고기볶음밥 + 간장버터장조림볶음밥]                 9
# 비비고 왕교자 1.05KGx4개+비비고 찐만두 168gx1개                                    8
#                                                                     ..
# [복날 준비 특가]누룽지닭백숙죽/전복삼계죽/녹두닭죽 外 + 보양닭백숙죽 증정                           1
# 비비고 순살삼치구이 60G X 3개                                                  1
# [CJ직배송]CJ 꼬마 돈까스 400G X3개                                            1
# [CJ직배송]비비고 도톰동그랑땡 425G*2 X2개                                         1
# 햇반/쿡반불고기주먹밥500G+햇반/쿡반김치치즈주먹밥500G+햇반/쿡반버터장조림주먹밥500G+햇반/쿡반치즈닭갈비500     1
# Name: 판매자상품명, Length: 73, dtype: int64

# %%
# 상품별로 많이 사는 제품 시각화 -> 곰탕, 즉석밥, 만두, 식용유 등이 과반수를 차지하는 것을 알 수 있다.

df_mem1_1_top10 = df_mem1_1['판매자상품명'].value_counts().head(10).index

plt.figure(figsize=(12, 5))
sns.countplot(y='판매자상품명', data=df_mem1_1, order=[df_mem1_1_top10[i] for i in range(0,10)])
# Out:
# <AxesSubplot:xlabel='count', ylabel='판매자상품명'>

# %%
df_mem1_1.groupby(['시간대 대분류','표준카테고리']).count()
# Out:
#                                     주문접수일시  주문번호  유입채널 대분류  주문월  아이디  판매자상품명  \
# 시간대 대분류 표준카테고리
# 00 ~ 03 가공식품 > 면류 > 기타면류                 1     1         1    1    1       1
#         가공식품 > 식용유/오일 > 식용유/오일선물세트       2     2         2    2    2       2
#         가공식품 > 식용유/오일 > 카놀라유             1     1         1    1    1       1
#         과자/간식 > 캔디/껌/캐러멜 > 젤리/푸딩         1     1         1    1    1       1
#         김치/반찬 > 김치 > 포기김치                1     1         1    1    1       1
# ...                                    ...   ...       ...  ...  ...     ...
# 21 ~ 00 냉장/냉동/간편식 > 떡볶이/만두 > 만두          9     9         9    9    9       9
#         냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥       1     1         1    1    1       1
#         냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥       5     5         5    5    5       5
#         정육/계란 > 양념육 > 기타양념육              1     1         1    1    1       1
#         커피/생수/음료 > 주스/과즙음료 > 과일음료        1     1         1    1    1       1
#
# ...

# %%
# 카테고리별로 많이 사는 제품 시각화
# 같은 상품인데도 제품별로 이름이 조금씩 다르기 때문에, 한 번 더 확인해줍니다.
# ex. 앞에 '[2+1]'이나 '[CJ직배송]'', 내지는 '*1개, *3개' 처럼 같은 상품인데도 상품명이 다르기 때문에 카테고리로 묶어주겠습니다.

df_mem1_1_top_category = df_mem1_1['표준카테고리'].value_counts().head(5).index
plt.figure(figsize=(12, 10))
sns.countplot(y='표준카테고리', data=df_mem1_1, order=[df_mem1_1_top_category[i] for i in range(0,5)], hue='시간대 대분류')
# Out:
# <AxesSubplot:xlabel='count', ylabel='표준카테고리'>

# %%
df_mem1_2_top10 = df_mem1_2['판매자상품명'].value_counts().head(10).index

plt.figure(figsize=(12, 10))
sns.countplot(y='판매자상품명', data=df_mem1_2, order=[df_mem1_2_top10[i] for i in range(0,10)], hue='시간대 대분류')
# Out:
# <AxesSubplot:xlabel='count', ylabel='판매자상품명'>

# %% [markdown]
# * 이 회원은 주로 즉석밥(볶음밥), 국/탕(곰탕), 만두(교자), 식용유(포도씨유)를 구매하는 것을 알 수 있으며,
# * 주문량이 많은 21 ~ 00 시에 국/탕을 살때 만두를 함께 구매하는 것으로도 볼 수 있을 것 같습니다.
# * 그가 주로 주문하는 제품(혹은 같은 카테고리 내 판매량 많은 제품)이 할인 기간이거나,
# * 국/탕과 만두를 묶음으로 판매하는 할인 이벤트를 할 때
# * CJ 앱/사이트에서는 21 ~ 03시에,
# * 가격비교 사이트에서는 12 ~ 00시 사이에 광고를 활성화하여 재구매를 유도하면 좋을 것 같습니다.

# %% [markdown]
# # 1. 아이디와 카테고리로 그룹화하여 개인별 구매 패턴을 확인해보겠습니다.

# %%
df_id_test1 = df_id.groupby(['아이디', '표준카테고리']).count()

# %%
# 그래도 2번 이상 특정 회원이 특정 상품을 구매한 데이터들에 대하여 패턴을 찾는 것이 중요할 것이라고 생각하였습니다.
# 변수별로 na 값이 아니고서야, count수가 모두 같기에, 대표하는 변수 '주문접수 일시'로 검색하였습니다.

df_id_cond1 = df_id_test1[df_id_test1['주문접수일시'] >= 2]

# %%
df_id_cond1
# Out:
#                                        주문접수일시  주문번호  유입채널 대분류  시간대 대분류  주문월  \
# 아이디       표준카테고리
# -_-i****  냉장/냉동/간편식 > 떡볶이/만두 > 만두          14    14        14       14   14
# -_-ing    냉장/냉동/간편식 > 떡볶이/만두 > 만두           7     7         7        7    7
# 0107****  냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥       15    15        15       15   15
# 0109eun   냉장/냉동/간편식 > 돈가스/고로케/너겟 > 너겟       2     2         2        2    2
# 0111125   냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥        3     3         3        3    3
# ...                                       ...   ...       ...      ...  ...
# zzqz****  냉장/냉동/간편식 > 떡볶이/만두 > 만두           2     2         2        2    2
# zzx1832aa 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕          3     3         3        3    3
# zzzz****  가공식품 > 식용유/오일 > 식용유/오일선물세트        2     2         2        2    2
#           냉장/냉동/간편식 > 떡볶이/만두 > 만두           2     2         2        2    2
#           냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥        4     4         4        4    4
#
# ...

# %%
df_id_cond1.sort_values(by='주문접수일시', ascending=False)
# Out:
#                                             주문접수일시  주문번호  유입채널 대분류  시간대 대분류  \
# 아이디          표준카테고리
# csh3718      냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥        165   165       165      165
# jackal1104   냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥        122   122       122      122
# urimiracle   냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥         91    91        91       91
# dpalwl12     냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥         88    88        88       88
# yoon****     냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥         79    79        79       79
# ...                                            ...   ...       ...      ...
# kysw****     김치/반찬 > 김치 > 포기김치                   2     2         2        2
# kyun****     가공식품 > 장류 > 된장/쌈장/청국장               2     2         2        2
#              냉장/냉동/간편식 > 햄/소시지/베이컨 > 햄/소시지       2     2         2        2
# chanheumchol 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕            2     2         2        2
# ko11****     가공식품 > 식용유/오일 > 식용유/오일선물세트          2     2         2        2
#
# ...

# %%
df_uri = df_id[(df_id['아이디'] == 'urimiracle') & (df_id['표준카테고리'] == '냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥')]

# %%
# (아이디, 상품명)을 카운트하여, 예시로 urimiracle님의 데이터를 조사해보겠습니다.

df_id_cond1[df_id_cond1['주문접수일시'] == 91].index
# Out:
# MultiIndex([('urimiracle', '냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥')],
#            names=['아이디', '표준카테고리'])

# %%
df_uri = df_id[(df_id['아이디'] == 'urimiracle') & (df_id['표준카테고리'] == '냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥')]

# %%
df_uri['판매자상품명'].value_counts()
# Out:
# [CJ직배송] New 햇반 210g*3입X 8개(총24개)    34
# [CJ직배송]햇반 발아현미밥 210gX36개[1박스]       28
# [CJ직배송]햇반 매일찰잡곡밥 210G*3 X6개         10
# [CJ직배송]햇반 100%현미로 지은밥 130G x36개      9
# 햇반 100% 현미로 지은밥 130G*3 x12           4
# [CJ직배송]햇반 발아현미밥210g*3EA X6개          3
# CJ 햇반 큰공기 300G x18                   2
# [CJ직배송]햇반 매일콩잡곡밥 210G*3EA X6개        1
# Name: 판매자상품명, dtype: int64

# %% [markdown]
# ### urimiracle님의 경우, 가격 비교를 통해서 주로 06~18시에 즉석밥 종류를 주문하는구나!!, -> 패턴 파악

# %%
df_uri['유입채널 대분류'].value_counts()
# Out:
# 가격비교        83
# CJ 앱/사이트     6
# 검색           2
# Name: 유입채널 대분류, dtype: int64

# %%
df_uri['시간대 대분류'].value_counts()
# Out:
# 06 ~ 09    36
# 09 ~ 12    27
# 12 ~ 15    16
# 15 ~ 18    12
# Name: 시간대 대분류, dtype: int64

# %%
# 판매가는 대략 어느 정도에서 형성하거나, 할인하는 것이 좋을까?

df_uri.groupby(['판매자상품명', '판매가']).count()
# Out:
#                                         주문접수일시  주문번호  유입채널 대분류  시간대 대분류  주문월  \
# 판매자상품명                           판매가
# CJ 햇반 큰공기 300G x18               38800       2     2         2        2    2
# [CJ직배송] New 햇반 210g*3입X 8개(총24개) 33000      34    34        34       34   34
# [CJ직배송]햇반 100%현미로 지은밥 130G x36개  43200       5     5         5        5    5
#                                  45000       1     1         1        1    1
#                                  60000       3     3         3        3    3
# [CJ직배송]햇반 매일찰잡곡밥 210G*3 X6개      26920      10    10        10       10   10
# [CJ직배송]햇반 매일콩잡곡밥 210G*3EA X6개    26920       1     1         1        1    1
# [CJ직배송]햇반 발아현미밥 210gX36개[1박스]    47800      28    28        28       28   28
# [CJ직배송]햇반 발아현미밥210g*3EA X6개      28770       3     3         3        3    3
# 햇반 100% 현미로 지은밥 130G*3 x12       53000       4     4         4        4    4
#
#                                         아이디  표준카테고리  주문날짜
# ...

# %% [markdown]
# 가격비교로 구매한 상품 중 많이 산 상품을 파악해서 가격대를 모니터링한다.

# %% [markdown]
# # 유입채널 별 월별 상품 간 상관관계 분석

# %%
df_id
# Out:
#                    주문접수일시              주문번호  유입채널 대분류  시간대 대분류  주문월       아이디  \
# 0     2022-01-07 06:55:35  2022010712865550      가격비교  06 ~ 09    1  love****
# 1     2022-01-07 06:57:53  2022010712865630      가격비교  06 ~ 09    1  love****
# 2     2022-01-10 09:36:32  2022011013280040        검색  09 ~ 12    1  love****
# 3     2022-01-10 11:56:34  2022011013300450  CJ 앱/사이트  09 ~ 12    1  love****
# 4     2022-01-10 16:28:22  2022011013337260      가격비교  15 ~ 18    1  love****
# ...                   ...               ...       ...      ...  ...       ...
# 34705 2022-06-08 19:13:02  2022060814395670  CJ 앱/사이트  18 ~ 21    6  casc****
# 34706 2022-06-25 17:55:19  2022062516572530  CJ 앱/사이트  15 ~ 18    6  casc****
# 34707 2022-03-15 21:52:39  2022031512208870  CJ 앱/사이트  21 ~ 00    3  okji****
# 34708 2022-06-09 23:00:26  2022060914561580  CJ 앱/사이트  21 ~ 00    6  okji****
# 34709 2022-06-09 23:00:26  2022060914561580  CJ 앱/사이트  21 ~ 00    6  okji****
#
# ...

# %%
df_id_cj = df_id[df_id['유입채널 대분류'] == 'CJ 앱/사이트']

# %%
sns.countplot(x = '시간대 대분류', data = df_id_cj, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00']) #잠들기 전 시간인 21-00시를 노리자
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_cj.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:20]
# Out:
# 판매자상품명
# 비비고 사골곰탕 500g x18봉                                            1717
# [Lpoint 1,000P 지급]햇반 작은공기, 100% 현미밥 x 36개 특가 (1,000set 한정)    1362
# [CJ직배송] CJ 햇반 백미 210g x 36개                                   1200
# 비비고 BEST 볶음밥 3종 특가[불고기 비빔밥 + 매콤부추고기볶음밥 + 간장버터장조림볶음밥]          1087
# [CJ직배송]포도씨유 900ML X 2개                                         712
# CJ 햇반 쿡반 주먹밥 5종 골라담기                                           651
# [CJ직배송]햇반작은공기130G x36개                                         605
# [CJ직배송] New 햇반 210g*3입X 8개(총24개)                               579
# 비비고 왕교자 1.05KGx4개+비비고 찐만두 168gx1개                              531
# [6+3+5%추가쿠폰]비비고 프리미엄 죽 6개 골라담기 +보양닭백숙죽 3개 증정                   509
# CJ 스팸 25%라이트/ 스팸클래식 4개 골라담기 [ 택 1]                             480
# [6+3]비비고 프리미엄 죽 6개 골라담기 +통단팥죽 3개 증정                            468
# 미역국 X 5개 + 사골곰탕 X2개+ 육개장300g 2봉 증정(증정품 유통기한 22년 10월 7일까지)      420
# 햇반 작은공기/100% 현미밥130g x 36개                                     376
# ...

# %%
df_id_cj.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:20]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥       9720
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕         3410
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두          2555
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥       1720
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스     1282
# 과자/간식 > 캔디/껌/캐러멜 > 젤리/푸딩          836
# 가공식품 > 식용유/오일 > 식용유/오일선물세트        697
# 가공식품 > 소스/드레싱 > 기타소스              616
# 가공식품 > 장류 > 고추장/초고추장              615
# 가공식품 > 식용유/오일 > 카놀라유              600
# 가공식품 > 면류 > 기타면류                  559
# 가공식품 > 통조림/캔 > 햄통조림               534
# 가공식품 > 통조림/캔 > 캔/통조림선물세트          528
# 김치/반찬 > 김치 > 포기김치                 426
# 가공식품 > 장류 > 된장/쌈장/청국장             415
# 냉장/냉동/간편식 > 피자/핫도그/햄버거 > 핫도그      396
# 가공식품 > 조미료/양념 > 가공조미료             281
# 냉장/냉동/간편식 > 햄/소시지/베이컨 > 햄/소시지     275
# 가공식품 > 소스/드레싱 > 굴소스/중화요리소스        243
# 김치/반찬 > 반찬 > 기타반찬                 206
# Name: 주문번호, dtype: int64

# %% [markdown]
# # 각 월마다 21-00시가 제일 많다.

# %% [markdown]
# # 1월

# %%
df_id_cj1=df_id_cj[df_id_cj['주문월']==1]

# %%
sns.countplot(x = '시간대 대분류', data = df_id_cj1, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_cj1.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 판매자상품명
# [CJ직배송]CJ비비고왕교자1.05KG X 2개         42
# [CJ직배송][22년 설 선물세트]스팸마일드8호         35
# [CJ직배송][22년 설 선물세트]스팸3호            33
# CJ 비비고 사골곰탕 500g x18봉              31
# [CJ직배송]특별한선택 Y호                    30
# [CJ직배송]포도씨유 900ML X 2개             29
# CJ 비비고 새우볶음밥 420g x3               20
# CJ 비비고 차돌깍두기볶음밥 410g x3            18
# [CJ직배송] 최저가 혜택! 22년 설 선물 스팸 S2호    16
# [롯데ON] 비비고 고등어구이 60g X 5개          15
# Name: 주문번호, dtype: int64

# %%
df_id_cj1.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 가공식품 > 통조림/캔 > 캔/통조림선물세트         161
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두          115
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕          60
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥        54
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥        54
# 가공식품 > 식용유/오일 > 카놀라유              44
# 수산/건어물 > 생선 > 반조리생선               36
# 김치/반찬 > 반찬 > 기타반찬                 31
# 냉장/냉동/간편식 > 햄/소시지/베이컨 > 햄/소시지     29
# 가공식품 > 장류 > 된장/쌈장/청국장             29
# Name: 주문번호, dtype: int64

# %% [markdown]
# ### -> 통조림 > 만두 > 국/탕 > 밥종류 > 기름

# %% [markdown]
# # 2월

# %%
df_id_cj2=df_id_cj[df_id_cj['주문월']==2]

# %%
sns.countplot(x = '시간대 대분류', data = df_id_cj2, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_cj2.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 판매자상품명
# [CJ]비비고 왕교자 골라담기 + 수제고기만두 증정!                        21
# CJ 다담 부대찌개양념 140g x10                                19
# CJ 다담 순두부찌개 양념 140g x10                              16
# [CJ직배송] CJ 고메 함박스테이크 152gx10개                        15
# [CJ직배송]다담 순두부찌개양념 130G X10개                          14
# CJ 고메 바삭튀겨낸통등심돈카츠 450Gx3개                            14
# [CJ직배송]포도씨유 900ML X 2개                               11
# [롯데ON] 비비고 주먹밥 4종/불고기500+치즈500+버터장조림500+치즈닭갈비500G    11
# CJ 고메 바삭튀겨낸모짜렐라돈카츠 450Gx3개                           10
# [CJ직배송]CJ비비고왕교자1.05KG X 2개                           10
# Name: 주문번호, dtype: int64

# %%
df_id_cj2.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두            137
# 가공식품 > 소스/드레싱 > 굴소스/중화요리소스          75
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥          54
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕            46
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥          30
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스        30
# 정육/계란 > 양념육 > 기타양념육                 26
# 냉장/냉동/간편식 > 피자/핫도그/햄버거 > 피자/햄버거     19
# 수산/건어물 > 생선 > 반조리생선                 18
# 가공식품 > 소스/드레싱 > 기타소스                18
# Name: 주문번호, dtype: int64

# %% [markdown]
# ### ->  만두 > 중화요리소스 > 밥종류 > 국/탕 > 돈가스/육류

# %% [markdown]
# # 3월

# %%
df_id_cj3=df_id_cj[df_id_cj['주문월']==3]
sns.countplot(x = '시간대 대분류', data = df_id_cj3, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_cj3.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 판매자상품명
# [CJ직배송][CJ] 비비고 왕교자1.05KG X 3봉 + 수제고기만두 증정    257
# 천일염 소금/ 사골곰탕/비비고 죽/더비비고 특가 골라담기                92
# [특가+증정] CJ 비비고 왕교자 1.05kg X 3개 + 찐만두 증정        21
# 고메 바삭쫄깃한 탕수육 450gx3개                           20
# CJ 비비고 수제고기만두x2개+수제김치만두x2개                     16
# [CJ직배송]백설100%통참깨참기름300ML X 2개                  15
# CJ 브랜드데이 특가! 소금, 사골곰탕, 비비고 죽, 더비비고 최저가 보장      15
# CJ 고메 바삭튀겨낸통등심돈카츠 450Gx3개                      13
# [CJ제일제당] 비비고 수제만둣집 맛 진한고기만두400g*2번들X2EA        12
# 비비고 왕교자 1.05KGx4개+비비고 찐만두 168gx1개              11
# Name: 주문번호, dtype: int64

# %%
df_id_cj3.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두            405
# 가공식품 > 조미료/양념 > 가공조미료              119
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥          78
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕            71
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥          56
# 가공식품 > 장류 > 된장/쌈장/청국장               51
# 가공식품 > 장류 > 고추장/초고추장                44
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스        29
# 냉장/냉동/간편식 > 피자/핫도그/햄버거 > 피자/햄버거     25
# 냉장/냉동/간편식 > 동그랑땡/전/튀김 > 튀김류         20
# Name: 주문번호, dtype: int64

# %% [markdown]
# ### ->  만두 > 조미료 > 밥종류 > 국/탕

# %% [markdown]
# # 4월

# %%
df_id_cj4=df_id_cj[df_id_cj['주문월']==4]
sns.countplot(x = '시간대 대분류', data = df_id_cj4, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_cj4.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 판매자상품명
# [CJ직배송]포도씨유 900ML X 2개                   91
# 천일염 소금/ 사골곰탕/비비고 죽/더비비고 특가 골라담기          63
# 다담 된장찌개양념 530Gx3개                        51
# 다담 된장찌개양념 530G X 4개                      46
# CJ 해찬들 우리쌀로만든태양초골드고추장2kgP X 2개           33
# CJ 햇반 쿡반 주먹밥 5종 골라담기                     32
# [CJ직배송]더건강한 닭가슴살 직화 통살구이100G X 6개        26
# [6+3]비비고 프리미엄 죽 6개 골라담기 +보양닭백숙죽 3개 증정    21
# 고메 바삭쫄깃한 탕수육 450gx3개                     21
# C J하선정 집김치처럼 시원한 포기김치 5kg                17
# Name: 주문번호, dtype: int64

# %%
df_id_cj4.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥      166
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두         139
# 가공식품 > 조미료/양념 > 가공조미료            74
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕         73
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스     73
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥       63
# 가공식품 > 식용유/오일 > 식용유/오일선물세트       58
# 가공식품 > 장류 > 된장/쌈장/청국장            52
# 가공식품 > 장류 > 고추장/초고추장             49
# 김치/반찬 > 김치 > 포기김치                37
# Name: 주문번호, dtype: int64

# %% [markdown]
# ### 즉석밥 > 만두 > 조미료 >국/탕 > 돈가스

# %% [markdown]
# # 5월

# %%
df_id_cj5=df_id_cj[df_id_cj['주문월']==5]
sns.countplot(x = '시간대 대분류', data = df_id_cj5, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_cj5.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 판매자상품명
# [CJ직배송]포도씨유 900ML X 2개                           578
# [6+3+5%추가쿠폰]비비고 프리미엄 죽 6개 골라담기 +보양닭백숙죽 3개 증정     509
# 비비고 왕교자 1.05KGx4개+비비고 찐만두 168gx1개                367
# [5%추가쿠폰 확인!]비비고 왕교자 1.05KGx4개+비비고 찐만두 168gx1개    263
# [6+3]비비고 프리미엄 죽 6개 골라담기 +통단팥죽 3개 증정              155
# [2+1][3+2]CJ제일제당 쁘띠첼 미초 석류+청포도+복숭아 外 골라담기        153
# [3번들 초특가]CJ제일제당 쁘띠첼 미초 석류+청포도                    149
# [선착순 시크릿 쿠폰 확인!]고메 오리지널 핫도그 外 골라담기               132
# [CJ직배송]압착올리브유900ML X 2개                           77
# [사은품]  해찬들 우리쌀로만든태양초골드고추장 1kg X2개                 49
# Name: 주문번호, dtype: int64

# %%
df_id_cj5.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥      810
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두         771
# 가공식품 > 식용유/오일 > 식용유/오일선물세트      579
# 과자/간식 > 캔디/껌/캐러멜 > 젤리/푸딩        306
# 가공식품 > 식용유/오일 > 카놀라유            164
# 냉장/냉동/간편식 > 피자/핫도그/햄버거 > 핫도그    159
# 가공식품 > 장류 > 고추장/초고추장             99
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스     89
# 김치/반찬 > 김치 > 포기김치                73
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕         55
# Name: 주문번호, dtype: int64

# %% [markdown]
# ### 즉석밥 > 만두 > 기름선물세트 > 젤리/푸딩

# %% [markdown]
# # 6월

# %%
df_id_cj6=df_id_cj[df_id_cj['주문월']==6]
sns.countplot(x = '시간대 대분류', data = df_id_cj6, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_6.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 판매자상품명
# 비비고 사골곰탕 500g x18봉                                               1545
# [Lpoint 1,000P 지급]햇반 작은공기, 100% 현미밥 x 36개 특가 (1,000set 한정)       1426
# 비비고 BEST 볶음밥 3종 특가[불고기 비빔밥 + 매콤부추고기볶음밥 + 간장버터장조림볶음밥]             1091
# CJ 햇반 쿡반 주먹밥 5종 골라담기                                              334
# [6+3]비비고 프리미엄 죽 6개 골라담기 +통단팥죽 3개 증정                               327
# [복날 준비 특가]누룽지닭백숙죽/전복삼계죽/녹두닭죽 外 + 보양닭백숙죽 증정                        281
# 왕교자 1.05kgx2 + 김치왕교자 420gx2                                       259
# [Lpoint 1,000P 지급]햇반 작은공기/100% 현미밥130g x 36개 특가 (1,000set 한정)     244
# 햇반 쿡반불고기500+치즈500+버터장조림500+치즈닭갈비500G                              238
# 미역국 X 5개 + 사골곰탕 X2개+ 영양꼬리곰탕 1봉 증정                                 234
# Name: 주문번호, dtype: int64

# %%
df_id_6.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥      3270
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕        2368
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥      1286
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두          736
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스     514
# 가공식품 > 소스/드레싱 > 기타소스             276
# 가공식품 > 면류 > 기타면류                 225
# 가공식품 > 장류 > 고추장/초고추장             220
# 커피/생수/음료 > 주스/과즙음료 > 과일음료        182
# 냉장/냉동/간편식 > 피자/핫도그/햄버거 > 핫도그     171
# Name: 주문번호, dtype: int64

# %% [markdown]
# ### 즉석밥 > 국/탕 > 만두 > 돈가스

# %% [markdown]
# # 7월

# %%
df_id_cj7=df_id_cj[df_id_cj['주문월']==7]
sns.countplot(x = '시간대 대분류', data = df_id_cj7, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_cj7.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 판매자상품명
# [CJ직배송]햇반작은공기130G x36개                            449
# 햇반 작은공기/100% 현미밥130g x 36개                        376
# [전참시 속 보양식사]누룽지닭백숙죽/전복삼계죽/녹두닭죽 外 + 보양닭백숙죽 증정      202
# 비비고 사골곰탕 500g x18봉                                156
# [6+6+6 선착순 특가]다담 정통된장찌개/청국장찌개/순두부찌개 外 골라담기        125
# [Lpoint&스벅커피쿠폰증정]햇반 솥반 프리미엄 6종 골라담기[택 1]           95
# [CJ직배송]CJ 고메 중화짬뽕 + 중화짜장 + 탕수육 + 깐풍기 세트            87
# CJ 햇반 쿡반 주먹밥 5종 골라담기                               81
# [6+2]비비고 용기형 단호박죽/통단팥죽/흑임자죽 + 버섯야채죽 280GX2개 증정     70
# [CJ직배송]쁘띠첼 5종 세트_30개(포도파인애플복숭아밀감 망고)               69
# Name: 주문번호, dtype: int64

# %%
df_id_cj7.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥      1505
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕         290
# 과자/간식 > 캔디/껌/캐러멜 > 젤리/푸딩         240
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스     207
# 가공식품 > 면류 > 기타면류                 177
# 가공식품 > 소스/드레싱 > 기타소스             167
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두          131
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥        86
# 김치/반찬 > 김치 > 포기김치                 80
# 가공식품 > 통조림/캔 > 닭가슴살통조림            50
# Name: 주문번호, dtype: int64

# %% [markdown]
# ### 즉석밥 > 국/탕 > 젤리/푸딩 > 돈가스 > 면류

# %% [markdown]
# # 8월

# %%
df_id_cj8=df_id_cj[df_id_cj['주문월']==8]
sns.countplot(x = '시간대 대분류', data = df_id_cj8, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_cj8.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 판매자상품명
# [CJ직배송] CJ 햇반 백미 210g x 36개                                  1168
# [CJ직배송] New 햇반 210g*3입X 8개(총24개)                              539
# CJ 스팸 25%라이트/ 스팸클래식 4개 골라담기 [ 택 1]                            479
# 미역국 X 5개 + 사골곰탕 X2개+ 육개장300g 2봉 증정(증정품 유통기한 22년 10월 7일까지)     374
# [CJ직배송]햇반 흑미밥 210gX36개[1박스]                                   363
# [CJ직배송]백설100%통참깨참기름300ML X 2개                                 295
# [L.Point 3,000p 증정]햇반 오곡밥 24입/ 솥반 7종 골라담기 [ 택 1]              280
# CJ 햇반 쿡반 주먹밥 5종 골라담기                                          265
# [컵반 배그에디션]이겼닭! 오늘 저녁은 치킨이닭(컵반 1개당 G코인 100~10,000코인 랜덤 증정)     222
# [햇반 솥반 X 서울체크인]햇반 솥반 7종                                       193
# Name: 주문번호, dtype: int64

# %%
df_id_cj8.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥      3784
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕         583
# 가공식품 > 통조림/캔 > 햄통조림              500
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스     367
# 가공식품 > 식용유/오일 > 카놀라유             297
# 가공식품 > 통조림/캔 > 캔/통조림선물세트         274
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두          189
# 가공식품 > 장류 > 고추장/초고추장             174
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥       142
# 과자/간식 > 캔디/껌/캐러멜 > 젤리/푸딩         109
# Name: 주문번호, dtype: int64

# %% [markdown]
# ## 즉석밥 > 통조림(선물세트) > 국/탕 > 돈가스

# %% [markdown]
# # 9월

# %%
df_id_cj9=df_id_cj[df_id_cj['주문월']==9]
sns.countplot(x = '시간대 대분류', data = df_id_cj9, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_cj9.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 판매자상품명
# [CJ직배송]햇반작은공기130G x36개                                     140
# 다담 된장찌개양념 530Gx2개                                           66
# [구매확정시 주문건당 5,000 Lpoint 자동적립] 스팸마일드8호 / *엘포인트 통합회원만 가능     50
# CJ 햇반 쿡반 주먹밥 5종 골라담기                                        34
# [CJ직배송]포도+사과+오렌지 워터젤리 총 30개[각10개씩]                          24
# [L포인트 3000p 증정]★LAST DAY EVENT★                             21
# [CJ직배송] New 햇반 210g*3입X 8개(총24개)                            17
# 비비고 사골곰탕 500g x18봉                                          16
# [6+6+6 선착순 특가]다담 정통된장찌개/청국장찌개/순두부찌개 外 골라담기                  14
# [CJ직배송]더건강한 닭가슴살 직화 통살구이100G X 6개                           13
# Name: 주문번호, dtype: int64

# %%
df_id_cj9.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥      304
# 가공식품 > 통조림/캔 > 캔/통조림선물세트         77
# 가공식품 > 소스/드레싱 > 칠리/살사소스          67
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스     63
# 과자/간식 > 캔디/껌/캐러멜 > 젤리/푸딩         57
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두          49
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕         48
# 가공식품 > 통조림/캔 > 닭가슴살통조림           42
# 가공식품 > 소스/드레싱 > 기타소스             38
# 김치/반찬 > 김치 > 포기김치                28
# Name: 주문번호, dtype: int64

# %% [markdown]
# ### 즉석밥 > 통조림세트 > 소스,돈가스 > 푸딩 > 만두

# %%
df_id_cj['표준카테고리'].nunique()
# Out:
# 58

# %%
df_idcj_tops = pd.DataFrame(data = [[0] * 9 for i in range(58)], 
                       columns=['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월'], 
                       index=df_id_cj['표준카테고리'].value_counts().sort_index().index )
df_idcj_tops['1월'] = df_id_cj1['표준카테고리'].value_counts().sort_values()
df_idcj_tops['2월'] = df_id_cj2['표준카테고리'].value_counts().sort_values()
df_idcj_tops['3월'] = df_id_cj3['표준카테고리'].value_counts().sort_values()
df_idcj_tops['4월'] = df_id_cj4['표준카테고리'].value_counts().sort_values()
df_idcj_tops['5월'] = df_id_cj5['표준카테고리'].value_counts().sort_values()
df_idcj_tops['6월'] = df_id_cj6['표준카테고리'].value_counts().sort_values()
df_idcj_tops['7월'] = df_id_cj7['표준카테고리'].value_counts().sort_values()
df_idcj_tops['8월'] = df_id_cj8['표준카테고리'].value_counts().sort_values()
df_idcj_tops['9월'] = df_id_cj9['표준카테고리'].value_counts().sort_values()

df_idcj_tops = df_idcj_tops.fillna(0)

# %%
df_idcj_tops = df_idcj_tops.transpose()

# %%
df_idcj_tops.corr()
# Out:
#                                    가공식품 > 면류 > 국수  가공식품 > 면류 > 기타면류  \
# 가공식품 > 면류 > 국수                           1.000000          0.614971
# 가공식품 > 면류 > 기타면류                         0.614971          1.000000
# 가공식품 > 면류 > 당면                           0.389409          0.100345
# 가공식품 > 면류 > 중화면                         -0.267059         -0.072089
# 가공식품 > 밀가루/믹스류 > 미숫가루                    0.072298          0.449369
# 가공식품 > 밀가루/믹스류 > 밀가루                     0.841965          0.874733
# 가공식품 > 밀가루/믹스류 > 베이킹믹스                   0.120184          0.330308
# 가공식품 > 밀가루/믹스류 > 튀김/부침가루                -0.273639         -0.196120
# 가공식품 > 소스/드레싱 > 굴소스/중화요리소스               0.560466          0.028615
# 가공식품 > 소스/드레싱 > 기타소스                     0.736930          0.964520
# 가공식품 > 소스/드레싱 > 칠리/살사소스                 -0.327292         -0.198348
# 가공식품 > 소스/드레싱 > 파스타소스                   -0.401639         -0.144882
# 가공식품 > 식용유/오일 > 기타오일                    -0.218380          0.181370
# ...

# %%
sns.barplot(y=df_idcj_tops.corr()['가공식품 > 통조림/캔 > 캔/통조림선물세트'].sort_values(ascending=False).index[1:6],
            x=df_idcj_tops.corr()['가공식품 > 통조림/캔 > 캔/통조림선물세트'].sort_values(ascending=False)[1:6])
# Out:
# <AxesSubplot:xlabel='가공식품 > 통조림/캔 > 캔/통조림선물세트'>

# %%
sns.barplot(y=df_idcj_tops.corr()['가공식품 > 장류 > 고추장/초고추장'].sort_values(ascending=False).index[1:6],
            x=df_idcj_tops.corr()['가공식품 > 장류 > 고추장/초고추장'].sort_values(ascending=False)[1:6])
# Out:
# <AxesSubplot:xlabel='가공식품 > 장류 > 고추장/초고추장'>

# %%
sns.barplot(y=df_idcj_tops.corr()['가공식품 > 식용유/오일 > 식용유/오일선물세트'].sort_values(ascending=False).index[1:6],
            x=df_idcj_tops.corr()['가공식품 > 식용유/오일 > 식용유/오일선물세트'].sort_values(ascending=False)[1:6])
# Out:
# <AxesSubplot:xlabel='가공식품 > 식용유/오일 > 식용유/오일선물세트'>

# %%
결론 같이 적어볼까요~~?

# %% [markdown]
# # 월별로 가격비교로 들어온 손님들 분석

# %%
df_id
# Out:
#                    주문접수일시              주문번호  유입채널 대분류  시간대 대분류  주문월       아이디  \
# 0     2022-01-07 06:55:35  2022010712865550      가격비교  06 ~ 09    1  love****
# 1     2022-01-07 06:57:53  2022010712865630      가격비교  06 ~ 09    1  love****
# 2     2022-01-10 09:36:32  2022011013280040        검색  09 ~ 12    1  love****
# 3     2022-01-10 11:56:34  2022011013300450  CJ 앱/사이트  09 ~ 12    1  love****
# 4     2022-01-10 16:28:22  2022011013337260      가격비교  15 ~ 18    1  love****
# ...                   ...               ...       ...      ...  ...       ...
# 34705 2022-06-08 19:13:02  2022060814395670  CJ 앱/사이트  18 ~ 21    6  casc****
# 34706 2022-06-25 17:55:19  2022062516572530  CJ 앱/사이트  15 ~ 18    6  casc****
# 34707 2022-03-15 21:52:39  2022031512208870  CJ 앱/사이트  21 ~ 00    3  okji****
# 34708 2022-06-09 23:00:26  2022060914561580  CJ 앱/사이트  21 ~ 00    6  okji****
# 34709 2022-06-09 23:00:26  2022060914561580  CJ 앱/사이트  21 ~ 00    6  okji****
#
# ...

# %%
df_id_g=df_id[df_id['유입채널 대분류']=="가격비교"]

# %%
df_id_g
# Out:
#                    주문접수일시              주문번호 유입채널 대분류  시간대 대분류  주문월       아이디  \
# 0     2022-01-07 06:55:35  2022010712865550     가격비교  06 ~ 09    1  love****
# 1     2022-01-07 06:57:53  2022010712865630     가격비교  06 ~ 09    1  love****
# 4     2022-01-10 16:28:22  2022011013337260     가격비교  15 ~ 18    1  love****
# 17    2022-03-01 16:16:20  2022030110171340     가격비교  15 ~ 18    3  love****
# 21    2022-03-10 13:32:41  2022031011458640     가격비교  12 ~ 15    3  love****
# ...                   ...               ...      ...      ...  ...       ...
# 34649 2022-07-01 08:05:17  2022070117332820     가격비교  06 ~ 09    7  csh7****
# 34677 2022-03-13 23:12:43  2022031311936770     가격비교  21 ~ 00    3  newn****
# 34679 2022-07-09 00:51:15  2022070918421180     가격비교  00 ~ 03    7  newn****
# 34686 2022-02-07 02:52:55  2022020717007150     가격비교  00 ~ 03    2  limm****
# 34687 2022-05-02 20:07:05  2022050219469290     가격비교  18 ~ 21    5  limm****
#
# ...

# %%
sns.countplot(x = '시간대 대분류', data = df_id_g, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])#역시 21-00시 많음
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %%
df_id_g['표준카테고리'].nunique()
# Out:
# 49

# %%
df_id_g1 = df_id_g[df_id_g['주문월'] == 1]
df_id_g2 = df_id_g[df_id_g['주문월'] == 2]
df_id_g3 = df_id_g[df_id_g['주문월'] == 3]
df_id_g4 = df_id_g[df_id_g['주문월'] == 4]
df_id_g5 = df_id_g[df_id_g['주문월'] == 5]
df_id_g6 = df_id_g[df_id_g['주문월'] == 6]
df_id_g7 = df_id_g[df_id_g['주문월'] == 7]
df_id_g8 = df_id_g[df_id_g['주문월'] == 8]
df_id_g9 = df_id_g[df_id_g['주문월'] == 9]

# %%
print("1월: " + df_id_g1['표준카테고리'].value_counts().head().index)
print("2월: " + df_id_g2['표준카테고리'].value_counts().head().index)
print("3월: " + df_id_g3['표준카테고리'].value_counts().head().index)
print("4월: " + df_id_g4['표준카테고리'].value_counts().head().index)
print("5월: " + df_id_g5['표준카테고리'].value_counts().head().index)
print("6월: " + df_id_g6['표준카테고리'].value_counts().head().index)
print("7월: " + df_id_g7['표준카테고리'].value_counts().head().index)
print("8월: " + df_id_g8['표준카테고리'].value_counts().head().index)
print("9월: " + df_id_g9['표준카테고리'].value_counts().head().index)
# Out:
# Index(['1월: 냉장/냉동/간편식 > 떡볶이/만두 > 만두', '1월: 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥',
#        '1월: 냉장/냉동/간편식 > 햄/소시지/베이컨 > 햄/소시지', '1월: 가공식품 > 장류 > 된장/쌈장/청국장',
#        '1월: 가공식품 > 통조림/캔 > 캔/통조림선물세트'],
#       dtype='object')
# Index(['2월: 냉장/냉동/간편식 > 떡볶이/만두 > 만두', '2월: 냉장/냉동/간편식 > 햄/소시지/베이컨 > 햄/소시지',
#        '2월: 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕', '2월: 정육/계란 > 양념육 > 기타양념육',
#        '2월: 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스'],
#       dtype='object')
# Index(['3월: 냉장/냉동/간편식 > 떡볶이/만두 > 만두', '3월: 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕',
#        '3월: 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스', '3월: 가공식품 > 소스/드레싱 > 굴소스/중화요리소스',
#        '3월: 냉장/냉동/간편식 > 피자/핫도그/햄버거 > 피자/햄버거'],
#       dtype='object')
# Index(['4월: 가공식품 > 장류 > 된장/쌈장/청국장', '4월: 냉장/냉동/간편식 > 햄/소시지/베이컨 > 햄/소시지',
#        '4월: 냉장/냉동/간편식 > 떡볶이/만두 > 만두', '4월: 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스',
#        '4월: 가공식품 > 식용유/오일 > 식용유/오일선물세트'],
#       dtype='object')
# Index(['5월: 가공식품 > 식용유/오일 > 식용유/오일선물세트', '5월: 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥',
# ...

# %% [markdown]
# ### 국/탕, 만두, 즉석밥, 햄/소시지, 돈가스는 매월 매출이 많아,
# ### 캔/통조림선물세트, 식용유/오일선물센트, 포기김치에 중점적으로 분석해보겠습니다!

# %%
df_idg_tops = pd.DataFrame(data = [[0] * 9 for i in range(49)], 
                       columns=['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월'], 
                       index=df_id_g['표준카테고리'].value_counts().sort_index().index )
df_idg_tops['1월'] = df_id_g1['표준카테고리'].value_counts().sort_values()
df_idg_tops['2월'] = df_id_g2['표준카테고리'].value_counts().sort_values()
df_idg_tops['3월'] = df_id_g3['표준카테고리'].value_counts().sort_values()
df_idg_tops['4월'] = df_id_g4['표준카테고리'].value_counts().sort_values()
df_idg_tops['5월'] = df_id_g5['표준카테고리'].value_counts().sort_values()
df_idg_tops['6월'] = df_id_g6['표준카테고리'].value_counts().sort_values()
df_idg_tops['7월'] = df_id_g7['표준카테고리'].value_counts().sort_values()
df_idg_tops['8월'] = df_id_g8['표준카테고리'].value_counts().sort_values()
df_idg_tops['9월'] = df_id_g9['표준카테고리'].value_counts().sort_values()

df_idg_tops = df_idg_tops.fillna(0)
df_idg_tops = df_idg_tops.transpose()

# %%
df_idg_tops.corr()
# Out:
#                                    가공식품 > 면류 > 기타면류  가공식품 > 면류 > 당면  \
# 가공식품 > 면류 > 기타면류                           1.000000    4.413320e-01
# 가공식품 > 면류 > 당면                             0.441332    1.000000e+00
# 가공식품 > 면류 > 중화면                            0.392816    5.187565e-01
# 가공식품 > 밀가루/믹스류 > 밀가루                       0.497194    8.838835e-01
# 가공식품 > 밀가루/믹스류 > 베이킹믹스                     0.116365   -1.767767e-01
# 가공식품 > 소스/드레싱 > 굴소스/중화요리소스                 0.096803    6.691176e-01
# 가공식품 > 소스/드레싱 > 기타소스                       0.821510    6.098807e-01
# 가공식품 > 소스/드레싱 > 칠리/살사소스                    0.662237    7.916926e-01
# 가공식품 > 소스/드레싱 > 파스타소스                      0.005655    6.614378e-01
# 가공식품 > 식용유/오일 > 기타오일                      -0.553535   -2.500000e-01
# 가공식품 > 식용유/오일 > 식용유/오일선물세트                 0.534237    9.930051e-01
# 가공식품 > 식용유/오일 > 참기름                        0.494712   -1.699675e-17
# 가공식품 > 식용유/오일 > 카놀라유                       0.435510    9.697204e-01
# ...

# %%
sns.barplot(y=df_idg_tops.corr()['가공식품 > 통조림/캔 > 캔/통조림선물세트'].sort_values(ascending=False).index[1:6],
            x=df_idg_tops.corr()['가공식품 > 통조림/캔 > 캔/통조림선물세트'].sort_values(ascending=False)[1:6])
# Out:
# <AxesSubplot:xlabel='가공식품 > 통조림/캔 > 캔/통조림선물세트'>

# %%
sns.barplot(y=df_idg_tops.corr()['가공식품 > 식용유/오일 > 식용유/오일선물세트'].sort_values(ascending=False).index[1:6],
            x=df_idg_tops.corr()['가공식품 > 식용유/오일 > 식용유/오일선물세트'].sort_values(ascending=False)[1:6])
# Out:
# <AxesSubplot:xlabel='가공식품 > 식용유/오일 > 식용유/오일선물세트'>

# %%
sns.barplot(y=df_idg_tops.corr()['김치/반찬 > 김치 > 포기김치'].sort_values(ascending=False).index[1:6],
            x=df_idg_tops.corr()['김치/반찬 > 김치 > 포기김치'].sort_values(ascending=False)[1:6])
# Out:
# <AxesSubplot:xlabel='김치/반찬 > 김치 > 포기김치'>

# %% [markdown]
# # 결론 ?

# %%
df_id_g.groupby('판매자상품명').count()
# Out:
#                                            주문접수일시  주문번호  유입채널 대분류  시간대 대분류  \
# 판매자상품명
#  숯불향바베큐바 280g*6                                 7     7         7        7
# 100%식물성 비비고 플랜테이블 왕교자 + 비비고 왕교자/수제만두 골라담기       1     1         1        1
# 20년 제일제면소 부산밀면 4인 1,734GX3개                     1     1         1        1
# C J하선정 집김치처럼 시원한 포기김치 5kg                      39    39        39       39
# CJ  숯불향닭강정 200g*6                               1     1         1        1
# ...                                           ...   ...       ...      ...
# 햇반 100% 현미로 지은밥 130G*3 x12                     11    11        11       11
# 햇반 BIG 컵반 골라담기                                  2     2         2        2
# 햇반 오곡밥 210g x24                                 1     1         1        1
# 햇반 작은공기/100% 현미밥130g x 36개                     19    19        19       19
# 햇반 컵반 중화마파두부덮밥 270G *6                          1     1         1        1
#
# ...

# %%
df_id_g.groupby('판매자상품명')['주문번호'].count().sort_values(ascending=False)[:20]
# Out:
# 판매자상품명
# [CJ직배송]포도씨유 900ML X 2개                        274
# [CJ직배송][CJ] 비비고 왕교자1.05KG X 3봉 + 수제고기만두 증정    206
# CJ 햇반 쿡반 주먹밥 5종 골라담기                          121
# [CJ직배송]햇반 100%현미로 지은밥 130G x36개               112
# 다담 된장찌개양념 530G X 4개                           107
# [CJ직배송] New 햇반 210g*3입X 8개(총24개)              103
# [CJ직배송] CJ 햇반 백미 210g x 36개                    93
# [CJ직배송]비비고 파김치800g                             77
# 비비고 사골곰탕 500g x18봉                             75
# [CJ직배송]더건강한 닭가슴살 직화 통살구이100G X 6개              59
# 다담 된장찌개양념 530Gx3개                              55
# [CJ직배송]햇반 발아현미밥 210gX36개[1박스]                  47
# CJ 해찬들 우리쌀로만든태양초골드고추장2kgP X 2개                 47
# [CJ직배송] 햇반 작은공기 130GX24개                       45
# [특가+증정] CJ 비비고 왕교자 1.05kg X 3개 + 찐만두 증정        41
# C J하선정 집김치처럼 시원한 포기김치 5kg                      39
# [CJ직배송]CJ비비고왕교자1.05KG X 2개                     36
# [CJ직배송]더건강한 닭가슴살 직화 스테이크100G X 6개              34
# [CJ직배송][한박스]더건강한 닭가슴살 직화 통살구이100gx24개          28
# ...

# %%
df_id_g.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False)[:10]
# Out:
# 표준카테고리
# 냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥       671
# 냉장/냉동/간편식 > 떡볶이/만두 > 만두          538
# 가공식품 > 식용유/오일 > 식용유/오일선물세트       272
# 냉장/냉동/간편식 > 돈가스/고로케/너겟 > 돈가스     231
# 가공식품 > 장류 > 된장/쌈장/청국장            231
# 김치/반찬 > 김치 > 포기김치                180
# 냉장/냉동/간편식 > 국/탕/찌개 > 국/탕         164
# 냉장/냉동/간편식 > 햄/소시지/베이컨 > 햄/소시지    147
# 가공식품 > 장류 > 고추장/초고추장             144
# 가공식품 > 소스/드레싱 > 굴소스/중화요리소스        98
# Name: 주문번호, dtype: int64

# %%
# 즉석밥 모니터링
df_id_g1 = df_id_g[df_id_g['표준카테고리'] == df_id_g.groupby('표준카테고리')['주문번호'].count().sort_values(ascending=False).index[0]]
df_id_g1[['판매자상품명', '판매가']]
df_id_g1.groupby(['판매자상품명', '판매가'])[['주문번호']].count()
# Out:
#                                                  주문번호
# 판매자상품명                                    판매가
# CJ 햇반 큰공기 300G x18                        32400     3
#                                           38690     1
#                                           38800     3
# [3/9 이후 출고][CJ직배송] CJ 햇반 발아현미밥 210Gx24개   40340     1
# [4/25 출고][CJ직배송] 햇반 100% 현미로 지은밥 130G x24 38890     2
# ...                                               ...
# 비비고 프리미엄 죽 6개 골라담기                        30700     2
# 햇반 100% 현미로 지은밥 130G*3 x12                53000    11
# 햇반 BIG 컵반 골라담기                            30480     2
# 햇반 오곡밥 210g x24                           31200     1
# 햇반 작은공기/100% 현미밥130g x 36개                34800    19
#
# [116 rows x 1 columns]

# %% [markdown]
# ### 다음과 같이 가격대를 모니터링하여, 가격비교 사이트에서는, 사람들이 많이 주문하는 가격대 상한선에서 이벤트를 진행하면 좋을 것 같다.

# %%
df_id.head()
# Out:
#                주문접수일시              주문번호  유입채널 대분류  시간대 대분류  주문월       아이디  \
# 0 2022-01-07 06:55:35  2022010712865550      가격비교  06 ~ 09    1  love****
# 1 2022-01-07 06:57:53  2022010712865630      가격비교  06 ~ 09    1  love****
# 2 2022-01-10 09:36:32  2022011013280040        검색  09 ~ 12    1  love****
# 3 2022-01-10 11:56:34  2022011013300450  CJ 앱/사이트  09 ~ 12    1  love****
# 4 2022-01-10 16:28:22  2022011013337260      가격비교  15 ~ 18    1  love****
#
#                             판매자상품명    판매가                      표준카테고리  \
# 0   [CJ직배송] CJ 햇반 매일잡곡밥 210g x 24개  36000  냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥
# 1   [CJ직배송] CJ 햇반 매일잡곡밥 210g x 24개  36000  냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥
# 2               CJ 고메 중화짜장 760Gx3개  21530             가공식품 > 면류 > 중화면
# 3       [CJ직배송]CJ비비고왕교자1.05KG X 2개  19920     냉장/냉동/간편식 > 떡볶이/만두 > 만두
# 4  [CJ직배송]쉐프솔루션 고기만땅왕교자 1.05KG X3개  20940     냉장/냉동/간편식 > 떡볶이/만두 > 만두
#
#         주문날짜
# 0 2022-01-07
# 1 2022-01-07
# 2 2022-01-10
# 3 2022-01-10
# 4 2022-01-10

# %%
df_id_m=df_id[df_id['유입채널 대분류']=="모바일 공유"]
df_id_m
# Out:
#                    주문접수일시              주문번호 유입채널 대분류  시간대 대분류  주문월       아이디  \
# 63    2022-05-16 01:37:14  2022051611214510   모바일 공유  00 ~ 03    5  love****
# 65    2022-05-16 01:47:55  2022051611215230   모바일 공유  00 ~ 03    5  love****
# 66    2022-05-16 06:16:09  2022051611222460   모바일 공유  06 ~ 09    5  love****
# 67    2022-05-16 07:10:43  2022051611224810   모바일 공유  06 ~ 09    5  love****
# 68    2022-05-16 08:37:09  2022051611231930   모바일 공유  06 ~ 09    5  love****
# ...                   ...               ...      ...      ...  ...       ...
# 34441 2022-05-16 01:32:23  2022051611214130   모바일 공유  00 ~ 03    5  ibbu****
# 34467 2022-06-08 05:43:46  2022060814305580   모바일 공유  03 ~ 06    6  pro2****
# 34468 2022-06-09 22:47:08  2022060914559760   모바일 공유  21 ~ 00    6  pro2****
# 34469 2022-06-09 22:53:54  2022060914560770   모바일 공유  21 ~ 00    6  pro2****
# 34525 2022-05-16 01:19:08  2022051611212910   모바일 공유  00 ~ 03    5  whal****
#
# ...

# %%
# 5월이 되어서야 갑작스럽게 활성화된 기능으로, 월별로 상품별로 분석하기엔 다소 어려워보인다.
df_id_m['주문월'].value_counts()
# Out:
# 5    480
# 8    195
# 6     75
# 7     37
# 9     27
# 3      8
# 4      8
# 1      2
# 2      1
# Name: 주문월, dtype: int64

# %%
sns.countplot(x = '시간대 대분류', data = df_id_m, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %% [markdown]
# ### -> 모바일 공유 플랫폼은 주로 오전시간대에 많이 이용하는 것으로 파악되며, 이 시간대에 CJ 광고를 활성화 하면 좋을 것 같다.

# %%
# 검색은 수가 너무 적어, 보류

df_id_s=df_id[df_id['유입채널 대분류']=="검색"]
df_id_s
# Out:
#                    주문접수일시              주문번호 유입채널 대분류  시간대 대분류  주문월       아이디  \
# 2     2022-01-10 09:36:32  2022011013280040       검색  09 ~ 12    1  love****
# 5     2022-01-13 22:17:23  2022011313815590       검색  21 ~ 00    1  love****
# 58    2022-05-09 15:20:15  2022050910368990       검색  15 ~ 18    5  love****
# 59    2022-05-09 15:20:15  2022050910368990       검색  15 ~ 18    5  love****
# 138   2022-06-14 14:45:15  2022061415143200       검색  12 ~ 15    6  love****
# ...                   ...               ...      ...      ...  ...       ...
# 33777 2022-05-05 17:16:47  2022050519865240       검색  15 ~ 18    5  spoo****
# 34050 2022-01-25 14:41:38  2022012515534390       검색  12 ~ 15    1  saka****
# 34210 2022-05-26 23:21:18  2022052612722350       검색  21 ~ 00    5  saei****
# 34211 2022-05-26 23:21:18  2022052612722350       검색  21 ~ 00    5  saei****
# 34440 2022-05-11 20:24:01  2022051110682590       검색  18 ~ 21    5  ibbu****
#
# ...

# %%
sns.countplot(x = '시간대 대분류', data = df_id_s, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %% [markdown]
# ### 21~00 시에 많이 이용하는 추세로 이 시간대에 활성화해보면 어떨까?

# %% [markdown]
# # 이벤트 광고

# %%
df_id_e=df_id[df_id['유입채널 대분류']=="기타 및 이벤트 광고"]
df_id_e
# Out:
#                    주문접수일시              주문번호     유입채널 대분류  시간대 대분류  주문월  \
# 8     2022-02-01 16:46:03  2022020116254690  기타 및 이벤트 광고  15 ~ 18    2
# 10    2022-02-05 23:55:52  2022020516835790  기타 및 이벤트 광고  21 ~ 00    2
# 27    2022-03-14 12:25:54  2022031411999810  기타 및 이벤트 광고  12 ~ 15    3
# 88    2022-05-25 21:22:03  2022052512579100  기타 및 이벤트 광고  21 ~ 00    5
# 97    2022-05-30 23:05:14  2022053013194100  기타 및 이벤트 광고  21 ~ 00    5
# ...                   ...               ...          ...      ...  ...
# 34559 2022-06-26 20:29:25  2022062616701110  기타 및 이벤트 광고  18 ~ 21    6
# 34647 2022-06-19 21:50:10  2022061915769800  기타 및 이벤트 광고  21 ~ 00    6
# 34648 2022-06-23 21:57:28  2022062316356330  기타 및 이벤트 광고  21 ~ 00    6
# 34653 2022-02-10 09:39:49  2022021017616530  기타 및 이벤트 광고  09 ~ 12    2
# 34703 2022-09-01 09:53:52  2022090115054160  기타 및 이벤트 광고  09 ~ 12    9
#
#             아이디                                             판매자상품명    판매가  \
# ...

# %%
sns.countplot(x = '시간대 대분류', data = df_id_e, order=['00 ~ 03', '03 ~ 06', '06 ~ 09', '09 ~ 12', '12 ~ 15', '15 ~ 18', '18 ~ 21', '21 ~ 00'])
# Out:
# <AxesSubplot:xlabel='시간대 대분류', ylabel='count'>

# %% [markdown]
# ### 이벤트를 통한 유입은, 다양한 배너에 홍보가 되어 사람들 활동 시간(취침 시간 이외)에 골고루 주문량이 많은 것을 확인할 수 있다.
