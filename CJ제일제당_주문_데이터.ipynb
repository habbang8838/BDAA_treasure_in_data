# %% [markdown]
# <a href="https://colab.research.google.com/github/habbang8838/BDAA_treasure_in_data/blob/main/CJ%EC%A0%9C%EC%9D%BC%EC%A0%9C%EB%8B%B9_%EC%A3%BC%EB%AC%B8_%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-47ccba274b6a> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount ('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     104       timeout_ms=timeout_ms,
#     105       ephemeral=True,
# --> 106       readonly=readonly)
#     107
#     108
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     123   if ephemeral:
#     124     _message.blocking_request(
# --> 125         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     126
#     127   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   request_id = send_request(
#     170       request_type, request, parent=parent, expect_reply=True)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     100         reply.get('colab_msg_id') == message_id):
#     101       if 'error' in reply:
# --> 102         raise MessageError(reply['error'])
#     103       return reply.get('data', None)
#     104
#
# MessageError: Error: credential propagation was unsuccessful

# %%
path = "/content/drive/MyDrive/"

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/CJ제일제당 주문 데이터(전처리).xlsx')

# %%
df
# Out:
#                    주문접수일시              주문번호    유입매체  주문구분  \
# 0     2022-01-01 00:38:13  2022010111866837  MO WEB  일반주문
# 1     2022-01-01 02:54:53  2022010111873735     APP  일반주문
# 2     2022-01-01 02:56:35  2022010111873774     APP  일반주문
# 3     2022-01-01 04:35:17  2022010111875631  MO WEB  일반주문
# 4     2022-01-01 08:00:37  2022010111879668     APP  일반주문
# ...                   ...               ...     ...   ...
# 93315 2022-09-30 23:52:25  2022093018638708  MO WEB  일반주문
# 93316 2022-09-30 23:52:41  2022093018638709     APP  일반주문
# 93317 2022-09-30 23:56:28  2022093018639349     APP  일반주문
# 93318 2022-09-30 23:58:52  2022093018639892     APP  일반주문
# 93319 2022-09-30 23:59:27  2022093018640098     APP  일반주문
#
#                         유입채널        회원구분           아이디     전시유입코드  \
# 0      [다음카카오] PCS 가격비교_롯데ON  LPOINT통합회원      kim6****        CHT
# 1                   디폴트 채널상세  LPOINT통합회원      savi****        RSI
# 2                   디폴트 채널상세  LPOINT통합회원      savi****        RSI
# 3      [다음카카오] PCS 가격비교_롯데ON  LPOINT통합회원      happ****        CHT
# 4                   디폴트 채널상세  LPOINT통합회원      cats****  SCH비비고추어탕
# ...                      ...         ...           ...        ...
# 93315    [네이버] PCS 가격비교_롯데ON  LPOINT통합회원       cha2844        CHT
# 93316               디폴트 채널상세  LPOINT통합회원        wocns2        CHT
# 93317               디폴트 채널상세  LPOINT통합회원       xraydos        RSI
# 93318       [링크프라이스] CPS_롯데온  LPOINT통합회원       badamit        NaN
# 93319               디폴트 채널상세  LPOINT통합회원  simsimfreeya    SCH사골곰탕
#
#                    상품주문번호  진행단계  ...                          전시단품명  \
# 0      2022010111866837_1  배송완료  ...                           단일상품
# 1      2022010111873735_1  배송완료  ...                           단일상품
# 2      2022010111873774_1  배송완료  ...                           단일상품
# 3      2022010111875631_1  배송완료  ...                           단일상품
# 4      2022010111879668_2  배송완료  ...                           단일상품
# ...                   ...   ...  ...                            ...
# 93315  2022093018638708_1  배송완료  ...                           단일상품
# 93316  2022093018638709_1  배송완료  ...             비비고 사골곰탕 500g x18봉
# 93317  2022093018639349_1  배송완료  ...              햇반 매일오곡밥 210Gx24개
# 93318  2022093018639892_1  배송완료  ...  프리미엄 육수세트 18봉[한우사골곰탕+진국육수 3종]
# 93319  2022093018640098_1  배송완료  ...             비비고 사골곰탕 500g x18봉
#
#             판매자상품번호                             판매자상품명  \
# 0      LO1135162715               CJ 다담 된장찌개양념 530G x3
# 1      LO1495023715                   비비고 국물요리 BEST 9종
# 2      LO1495023715                   비비고 국물요리 BEST 9종
# 3      LO1517718327             CJ 다담 된장찌개양념 530G X 4개
# 4      LO1249549902                비비고 남도식 추어탕 460Gx5개
# ...             ...                                ...
# 93315  LO1520770627  [CJ직배송]더건강한 닭가슴살 직화 스테이크100G X 6개
# 93316  LO1978869746    [L포인트 3000p 증정]★LAST DAY EVENT★
# 93317  LO1978869746    [L포인트 3000p 증정]★LAST DAY EVENT★
# 93318  LO1978869746    [L포인트 3000p 증정]★LAST DAY EVENT★
# 93319  LO1978869746    [L포인트 3000p 증정]★LAST DAY EVENT★
#
#                        판매자단품번호                         판매자단품명    판매가 수량  \
# 0      LO1135162715_1135162716                           단일상품  16240  1
# 1      LO1495023715_1495023716                           단일상품  33240  1
# 2      LO1495023715_1495023716                           단일상품  33240  1
# 3      LO1517718327_1517718328                           단일상품  21660  1
# 4      LO1249549902_1249549903                           단일상품  23680  1
# ...                        ...                            ...    ... ..
# 93315  LO1520770627_1520770628                           단일상품  17400  1
# 93316  LO1978869746_1978869755             비비고 사골곰탕 500g x18봉  24500  2
# 93317  LO1978869746_1978869753              햇반 매일오곡밥 210Gx24개  37000  1
# 93318  LO1978869746_1978869749  프리미엄 육수세트 18봉[한우사골곰탕+진국육수 3종]  38000  1
# 93319  LO1978869746_1978869755             비비고 사골곰탕 500g x18봉  24500  2
#
#                            표준카테고리    판매액 주문월
# 0           가공식품 > 장류 > 된장/쌈장/청국장  16240   1
# 1      냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥  33240   1
# 2      냉장/냉동/간편식 > 즉석밥/죽/스프 > 즉석밥  33240   1
# 3           가공식품 > 장류 > 된장/쌈장/청국장  21660   1
# 4        냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  23680   1
# ...                           ...    ...  ..
# 93315      가공식품 > 통조림/캔 > 닭가슴살통조림  17400   9
# 93316    냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  49000   9
# 93317    냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  37000   9
# 93318    냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  38000   9
# 93319    냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  49000   9
#
# [93320 rows x 25 columns]

# %% [markdown]
# 재구매율은 중요하다

# %%
df['아이디'].nunique()
# Out:
# 51324

# %%
len(df)
# Out:
# 93320

# %%
duple_df=df[df.duplicated(['아이디'],keep=False)]

# %%
duple_test=duple_df.groupby(['아이디','판매자상품명'])

# %%
duple_test.agg(lambda g:len(g))
# Out:
#                                              주문접수일시  주문번호  유입매체  주문구분  유입채널  \
# 아이디      판매자상품명
# *        CJ 고메 치킨순살크리스피 550G x3                   1     1     1     1     1
#          CJ 다담 냉이된장찌개양념 140g x10                  1     1     1     1     1
#          CJ 하선정 포기김치 3KG                          1     1     1     1     1
#          CJ 햇반 쿡반 주먹밥 5종 골라담기                     1     1     1     1     1
#          [100%식물성]비비고 플랜테이블 왕교자 골라담기              1     1     1     1     1
# ...                                             ...   ...   ...   ...   ...
# zzzz**** 비비고 사골곰탕 500g x18봉                       1     1     1     1     1
#          비비고 찰보리감자만두 600G x6                      1     1     1     1     1
#          해찬들 우리쌀로만든태양초골드고추장 2kg                   1     1     1     1     1
# zzzzbb   CJ 햇반 쿡반 주먹밥 5종 골라담기                     1     1     1     1     1
#          [CJ직배송]포도+사과+오렌지 워터젤리 총 30개[각10개씩]       1     1     1     1     1
#
#                                              회원구분  전시유입코드  상품주문번호  진행단계  \
# 아이디      판매자상품명
# *        CJ 고메 치킨순살크리스피 550G x3                 1       1       1     1
#          CJ 다담 냉이된장찌개양념 140g x10                1       1       1     1
#          CJ 하선정 포기김치 3KG                        1       1       1     1
#          CJ 햇반 쿡반 주먹밥 5종 골라담기                   1       1       1     1
#          [100%식물성]비비고 플랜테이블 왕교자 골라담기            1       1       1     1
# ...                                           ...     ...     ...   ...
# zzzz**** 비비고 사골곰탕 500g x18봉                     1       1       1     1
#          비비고 찰보리감자만두 600G x6                    1       1       1     1
#          해찬들 우리쌀로만든태양초골드고추장 2kg                 1       1       1     1
# zzzzbb   CJ 햇반 쿡반 주먹밥 5종 골라담기                   1       1       1     1
#          [CJ직배송]포도+사과+오렌지 워터젤리 총 30개[각10개씩]     1       1       1     1
#
#                                              주문완료일시  ...  전시상품명  전시단품명  \
# 아이디      판매자상품명                                      ...
# *        CJ 고메 치킨순살크리스피 550G x3                   1  ...      1      1
#          CJ 다담 냉이된장찌개양념 140g x10                  1  ...      1      1
#          CJ 하선정 포기김치 3KG                          1  ...      1      1
#          CJ 햇반 쿡반 주먹밥 5종 골라담기                     1  ...      1      1
#          [100%식물성]비비고 플랜테이블 왕교자 골라담기              1  ...      1      1
# ...                                             ...  ...    ...    ...
# zzzz**** 비비고 사골곰탕 500g x18봉                       1  ...      1      1
#          비비고 찰보리감자만두 600G x6                      1  ...      1      1
#          해찬들 우리쌀로만든태양초골드고추장 2kg                   1  ...      1      1
# zzzzbb   CJ 햇반 쿡반 주먹밥 5종 골라담기                     1  ...      1      1
#          [CJ직배송]포도+사과+오렌지 워터젤리 총 30개[각10개씩]       1  ...      1      1
#
#                                              판매자상품번호  판매자단품번호  판매자단품명  판매가  \
# 아이디      판매자상품명
# *        CJ 고메 치킨순살크리스피 550G x3                    1        1       1    1
#          CJ 다담 냉이된장찌개양념 140g x10                   1        1       1    1
#          CJ 하선정 포기김치 3KG                           1        1       1    1
#          CJ 햇반 쿡반 주먹밥 5종 골라담기                      1        1       1    1
#          [100%식물성]비비고 플랜테이블 왕교자 골라담기               1        1       1    1
# ...                                              ...      ...     ...  ...
# zzzz**** 비비고 사골곰탕 500g x18봉                        1        1       1    1
#          비비고 찰보리감자만두 600G x6                       1        1       1    1
#          해찬들 우리쌀로만든태양초골드고추장 2kg                    1        1       1    1
# zzzzbb   CJ 햇반 쿡반 주먹밥 5종 골라담기                      1        1       1    1
#          [CJ직배송]포도+사과+오렌지 워터젤리 총 30개[각10개씩]        1        1       1    1
#
#                                              수량  표준카테고리  판매액  주문월
# 아이디      판매자상품명
# *        CJ 고메 치킨순살크리스피 550G x3               1       1    1    1
#          CJ 다담 냉이된장찌개양념 140g x10              1       1    1    1
#          CJ 하선정 포기김치 3KG                      1       1    1    1
#          CJ 햇반 쿡반 주먹밥 5종 골라담기                 1       1    1    1
#          [100%식물성]비비고 플랜테이블 왕교자 골라담기          1       1    1    1
# ...                                          ..     ...  ...  ...
# zzzz**** 비비고 사골곰탕 500g x18봉                   1       1    1    1
#          비비고 찰보리감자만두 600G x6                  1       1    1    1
#          해찬들 우리쌀로만든태양초골드고추장 2kg               1       1    1    1
# zzzzbb   CJ 햇반 쿡반 주먹밥 5종 골라담기                 1       1    1    1
#          [CJ직배송]포도+사과+오렌지 워터젤리 총 30개[각10개씩]   1       1    1    1
#
# [40135 rows x 23 columns]

# %%
duple_test.filter(lambda g:len(g)>2)
# Out:
#                    주문접수일시              주문번호 유입매체  주문구분  \
# 12    2022-01-01 12:42:46  2022010111905645   PC  일반주문
# 53    2022-01-03 01:28:14  2022010312126640  APP  일반주문
# 64    2022-01-03 08:10:15  2022010312149761  APP  일반주문
# 81    2022-01-03 10:51:58  2022010312195489  APP  일반주문
# 91    2022-01-03 12:15:10  2022010312219266  APP  일반주문
# ...                   ...               ...  ...   ...
# 93258 2022-09-30 22:16:05  2022093018626718  APP  일반주문
# 93291 2022-09-30 23:07:50  2022093018632558  APP  일반주문
# 93295 2022-09-30 23:10:44  2022093018632985  APP  일반주문
# 93296 2022-09-30 23:13:29  2022093018633261  APP  일반주문
# 93297 2022-09-30 23:16:33  2022093018633685  APP  일반주문
#
#                            유입채널        회원구분       아이디      전시유입코드  \
# 12          [네이버] PCS 가격비교_롯데ON  LPOINT통합회원  shrh****         CHT
# 53     [롯데ON][PUSH][실시간 BEST 🕠]  LPOINT통합회원  toy2****   SCH깍두기볶음밥
# 64                     디폴트 채널상세  LPOINT통합회원  kiwi****         MLT
# 81                     디폴트 채널상세  LPOINT통합회원  y312****         SCT
# 91        [롯데ON][🐯해피 뉴 퍼스트먼데이🐯]  LPOINT통합회원  tcho****  SCH씨제이마라탕면
# ...                         ...         ...       ...         ...
# 93258          [링크프라이스] CPS_롯데온  LPOINT통합회원  chanyi80         NaN
# 93291                  디폴트 채널상세  LPOINT통합회원   byc0157         SCT
# 93295                  디폴트 채널상세  LPOINT통합회원   byc0157         MLT
# 93296                  디폴트 채널상세  LPOINT통합회원   byc0157         RSI
# 93297                  디폴트 채널상세  LPOINT통합회원   byc0157         RSI
#
#                    상품주문번호  진행단계  ...  \
# 12     2022010111905645_1  배송완료  ...
# 53     2022010312126640_3  배송완료  ...
# 64     2022010312149761_2  배송완료  ...
# 81     2022010312195489_2  배송완료  ...
# 91     2022010312219266_1  배송완료  ...
# ...                   ...   ...  ...
# 93258  2022093018626718_1  배송완료  ...
# 93291  2022093018632558_1  배송완료  ...
# 93295  2022093018632985_1  배송완료  ...
# 93296  2022093018633261_1  배송완료  ...
# 93297  2022093018633685_1  배송완료  ...
#
#                                                    전시단품명       판매자상품번호  \
# 12                                                  단일상품  LO1009737185
# 53                                                  단일상품  LO1031675323
# 64                                                  단일상품  LO1134972875
# 81     [옵션1][조리용타이머 증정] 비비고 도가니곰탕 460G X2개 + 비비고 꼬리곰탕...  LO1628545493
# 91                                                  단일상품  LO1045014153
# ...                                                  ...           ...
# 93258                                               단일상품  LO1032764663
# 93291                                 비비고 사골곰탕 500g x18봉  LO1978869746
# 93295                                 비비고 사골곰탕 500g x18봉  LO1978869746
# 93296                           햇반 매일콩잡곡밥 210g x 3 x 12개  LO1978869746
# 93297                           햇반 매일콩잡곡밥 210g x 3 x 12개  LO1978869746
#
#                                  판매자상품명                  판매자단품번호  \
# 12                       숯불향바베큐바 280g*6  LO1009737185_1009737193
# 53              CJ 비비고 차돌깍두기볶음밥 410g x3  LO1031675323_1031675324
# 64                맥스봉치즈 1.08KG(27G*40개)  LO1134972875_1134972876
# 81     [조리용타이머 증정]비비고 도가니곰탕 & 꼬리곰탕 골라담기  LO1628545493_1628545494
# 91                   사천마라탕면 2인분 434G x4  LO1045014153_1045014154
# ...                                 ...                      ...
# 93258                비비고 사골곰탕 500g x18봉  LO1032764663_1032764664
# 93291   [L포인트 3000p 증정]★LAST DAY EVENT★  LO1978869746_1978869755
# 93295   [L포인트 3000p 증정]★LAST DAY EVENT★  LO1978869746_1978869755
# 93296   [L포인트 3000p 증정]★LAST DAY EVENT★  LO1978869746_1978869748
# 93297   [L포인트 3000p 증정]★LAST DAY EVENT★  LO1978869746_1978869748
#
#                                                   판매자단품명    판매가 수량  \
# 12                                                  단일상품  24000  1
# 53                                                  단일상품  15480  1
# 64                                                  단일상품  15900  2
# 81     [옵션1][조리용타이머 증정] 비비고 도가니곰탕 460G X2개 + 비비고 꼬리곰탕...  26580  1
# 91                                                  단일상품  23920  1
# ...                                                  ...    ... ..
# 93258                                               단일상품  24600  2
# 93291                                 비비고 사골곰탕 500g x18봉  24500  2
# 93295                                 비비고 사골곰탕 500g x18봉  24500  2
# 93296                           햇반 매일콩잡곡밥 210g x 3 x 12개  54000  1
# 93297                           햇반 매일콩잡곡밥 210g x 3 x 12개  54000  1
#
#                               표준카테고리    판매액 주문월
# 12       냉장/냉동/간편식 > 돈가스/고로케/너겟 > 너겟  24000   1
# 53        냉장/냉동/간편식 > 즉석밥/죽/스프 > 볶음밥  15480   1
# 64     냉장/냉동/간편식 > 햄/소시지/베이컨 > 햄/소시지  31800   1
# 81          냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  26580   1
# 91                   가공식품 > 면류 > 중화면  23920   1
# ...                              ...    ...  ..
# 93258       냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  49200   9
# 93291       냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  49000   9
# 93295       냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  49000   9
# 93296       냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  54000   9
# 93297       냉장/냉동/간편식 > 국/탕/찌개 > 국/탕  54000   9
#
# [9808 rows x 25 columns]

# %% [markdown]
# 재구매 패턴을 파악할 수 있는 코드...
# 재구매 기간을 알아보고 그에 맞는 push 알림을 준다.

# %% [markdown]
# 같은 아이디의 시간대를 파악하여서 어떤 시간대에 광고를 넣는 것이 좋은지 알아본다.

# %% [markdown]
# 가격비교로 구매한 상품 중 많이 산 상품을 파악해서 가격대를 모니터링한다.

# %%
df['유입채널'].value_counts().head(43)
# Out:
# 디폴트 채널상세                            58484
# 유실 채널상세                             15562
# [네이버] PCS 가격비교_롯데ON                  7480
# [다음카카오] PCS 가격비교_롯데ON                1285
# [에누리] PCS 가격비교_롯데ON                  1256
# [모바일]다른앱공유하기                         1125
# [네이버] 키워드_쇼핑검색광고_롯데ON                 924
# [모바일]카카오톡                             902
# [다나와] PCS 가격비교_롯데ON                   799
# [링크프라이스] CPS_롯데온                      340
# [롯데ON] MO Web 행사장_21.07_월간APP혜택       332
# [네이버] MO_브랜드검색_롯데ON                   306
# [구글] SA_롯데ON                          269
# [샵백] CPS제휴_매출_롯데ON                    255
# [네이버] PC_브랜드검색_롯데ON                   242
# [롯데ON][알림톡][[롯데ON] 주문 완료 안내]          219
# [모지세] CPS제휴_매출_롯데ON                   177
# [롯데ON][PUSH][실시간 BEST 🕠]              164
# [네이버] 키워드_롯데ON                        135
# [롯데ON][알림톡][[롯데ON] 상품 배송시작 안내]        134
# [롯데ON][PUSH][🔔장바구니 알리미]               102
# [롯데ON][알림톡][[롯데ON] 배송완료 안내]           100
# [애피어] APP 리타게팅_롯데ON                    94
# [롯데ON][비비고 BEST 단 하루 혜택🙌]              72
# [롯데ON][알림톡][[롯데ON] 주문취소 안내]            69
# [클릭즈] 키워드CPS_애드타겟_롯데ON                 67
# [롯데ON][ONLY 72시간만⏰]                    64
# 브이피                                    63
# webtoapp_coupon                        59
# [클릭즈] 키워드CPS_인애드(2)_롯데ON               52
# [롯데ON][PUSH][⏰10월 8일⏰]                 52
# [클릭즈] 키워드CPS_포춘팝(2)_롯데ON               45
# [위메프] PCS 가격비교 할인제외 소재_롯데ON            44
# [RTB House] APP 리타게팅_롯데ON              39
# [롯데ON][실시간 베스트 상품 200 🕠]               37
# 딥링크_DA                                 37
# 핫딜광고_소재13                              36
# [몰로코] APP 리타게팅_롯데ON                    36
# 나이스 제휴                                 35
# 주문완료 배너                                34
# [롯데ON][PUSH][#{map1} 고객님, 서둘러요💨]       33
# [롯데ON][[72시간쿠폰⏰] 잊지마세요!]               33
# (광고) 0730_라스트찬스                        32
# Name: 유입채널, dtype: int64
